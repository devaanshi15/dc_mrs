# %%
import pandas as pd

# Load the dataset
file_path = 'your_dataset.csv'  # Replace with your file path
df = pd.read_csv('tmdb_5000_movies.csv')

# Size and Scope
num_records, num_features = df.shape
print(f"Number of records (rows): {num_records}")
print(f"Number of features (columns): {num_features}")

# Data Fields/Attributes
print("\nData Fields/Attributes:")
print(df.columns.tolist())

# Format
print(f"\nFile Format: CSV")

# Data Types
print("\nData Types:")
print(df.dtypes)

# Missing Values
print("\nMissing Values:")
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Number of records (rows): 4803
# Number of features (columns): 20
#
# Data Fields/Attributes:
# ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']
#
# File Format: CSV
#
# Data Types:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# ...

# %%
import pandas as pd

# Load the dataset
file_path = 'your_dataset.csv'  # Replace with your file path
df = pd.read_csv('tmdb_5000_credits.csv')

# Size and Scope
num_records, num_features = df.shape
print(f"Number of records (rows): {num_records}")
print(f"Number of features (columns): {num_features}")

# Data Fields/Attributes
print("\nData Fields/Attributes:")
print(df.columns.tolist())

# Format
print(f"\nFile Format: CSV")

# Data Types
print("\nData Types:")
print(df.dtypes)

# Missing Values
print("\nMissing Values:")
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Number of records (rows): 4803
# Number of features (columns): 4
#
# Data Fields/Attributes:
# ['movie_id', 'title', 'cast', 'crew']
#
# File Format: CSV
#
# Data Types:
# movie_id     int64
# title       object
# cast        object
# crew        object
# dtype: object
#
# Missing Values:
# Series([], dtype: int64)

# %%
from sklearn.base import BaseEstimator, RegressorMixin

# Modify the model to be compatible with scikit-learn
class RecommendationModel(BaseEstimator, RegressorMixin):
    def __init__(self):
        pass
    
    def fit(self, X, y):
        # Fit the model on training data
        # Placeholder implementation
        return self
    
    def predict(self, X):
        # Predict based on the input features
        return np.random.rand(len(X))  # Placeholder predictions for demonstration
    
    def get_params(self, deep=True):
        return {}
    
    def set_params(self, **params):
        return self

# Re-initialize the recommendation model
model = RecommendationModel()

# Fit the model on the training data
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# Perform Cross-Validation
kf = KFold(n_splits=5, random_state=42, shuffle=True)
cv_scores_mse = cross_val_score(model, X, y, cv=kf, scoring='neg_mean_squared_error')
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert MSE to RMSE

# Store results in a dictionary
evaluation_results = {
    'MSE': mse,
    'RMSE': rmse,
    'Cross-Validation RMSE (mean)': np.mean(cv_rmse_scores),
    'Cross-Validation RMSE (std dev)': np.std(cv_rmse_scores)
}

evaluation_results
# Out:
# {'MSE': 0.15038177521842022,
#  'RMSE': 0.38779089109779286,
#  'Cross-Validation RMSE (mean)': 0.4152418320576026,
#  'Cross-Validation RMSE (std dev)': 0.017247873669011284}
